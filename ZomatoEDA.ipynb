# %% [markdown]
# ## Zomato Dataset EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv(r"C:\Users\kulka\OneDrive\Desktop\Exploratory Data Analysis\Zomatodataset\zomato.csv",encoding= 'latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ### Missing value check
# ### Exploring numeriacal and categorial variables
# ### finding relationship between features

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isna().sum()>1]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df_country=pd.read_excel(r"C:\Users\kulka\OneDrive\Desktop\Exploratory Data Analysis\Zomatodataset\Country-Code.xlsx")

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#df_country=df_country.groupby(df[Country Code])
final=pd.merge(df,df_country,on="Country Code", how="left")

# %%
final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
country_names=final.Country.value_counts().index

# %%
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'South Africa',
#        'UAE', 'New Zealand', 'Turkey', 'Australia', 'Phillipines', 'Indonesia',
#        'Qatar', 'Singapore', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_val=final.Country.value_counts().values

# %%
# pie chart top 3 countries uses zomato
plt.pie(country_val[:3],labels=country_names[:3],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20a2f0a95b0>,
# ...
#  [Text(-1.082974277862112, 0.1927867046480056, 'India'),
#   Text(1.0772816964394372, -0.22240536530526556, 'United States'),
#   Text(1.0995865232164619, -0.030157552300104404, 'United Kingdom')],
#  [Text(-0.5907132424702428, 0.10515638435345759, '94.39%'),
#   Text(0.5876081980578747, -0.12131201743923574, '4.73%'),
#   Text(0.5997744672089791, -0.01644957398187513, '0.87%')])

# %% [markdown]
# Observation: Zomato maximum records or transaction are from india after USA and then UK

# %%
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings=final.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:'Rating_count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating_count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ##Observation
#
# 1.when ratings is bet 4.5 to 4.9 --- Excellent
# 2.when rating is bet 4.0 to 4.4 --- very good
# 3.when rating is bet 3.5 to 3.9 ---- good
# 4.when rating is bet 3.0 to 3.4 ---- average
# 5.when rating is bet 2.5 to 2.9 ---- average
# 6.when rating is bet 2.0 to 2.4 ---- poor

# %%
import matplotlib as plt
plt.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating", y= "Rating_count",data=ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating_count'>

# %%
import seaborn as sns
sns.barplot(x="Aggregate rating", y= "Rating_count",data=ratings,hue="Rating color",palette=["White",'Red','Orange','Yellow','Green','DarkGreen'] )
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating_count'>

# %% [markdown]
# Observation:
# 1. Not rated count is very high
# 2. maximum no of ratings are between 2.5 to 3.4

# %%
## count plot 
sns.countplot(x='Rating color', data =ratings,palette=["White",'Red','Orange','Yellow','Green','DarkGreen'])
# Out:
# C:\Users\kulka\AppData\Local\Temp\ipykernel_18816\488490314.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color', data =ratings,palette=["White",'Red','Orange','Yellow','Green','DarkGreen'])
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
### Find the countries name that has given 0 ratings
final[final['Rating color'] == 'White']['Country'].value_counts()
# Out:
# Country
# India             2139
# Brazil               5
# United States        3
# United Kingdom       1
# Name: count, dtype: int64

# %%
final[final['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# Observation: maximum no of 0 ratings are from indian customers

# %%
## find out which currency is used by which country?
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final.groupby(['Country', 'Currency']).size().reset_index(name='Count')
# Out:
#            Country                Currency  Count
# 0        Australia               Dollar($)     24
# 1           Brazil      Brazilian Real(R$)     60
# 2           Canada               Dollar($)      4
# 3            India      Indian Rupees(Rs.)   8652
# 4        Indonesia  Indonesian Rupiah(IDR)     21
# 5      New Zealand           NewZealand($)     40
# 6      Phillipines        Botswana Pula(P)     22
# 7            Qatar         Qatari Rial(QR)     20
# 8        Singapore               Dollar($)     20
# 9     South Africa                 Rand(R)     60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)     20
# 11          Turkey        Turkish Lira(TL)     34
# 12             UAE      Emirati Diram(AED)     60
# 13  United Kingdom              Pounds(£)     80
# 14   United States               Dollar($)    434

# %%
## which countries do have online deliveries option
homedelivery=final.groupby(['Country','Has Online delivery']).size().reset_index(name=homedelivery)

# %% [markdown]
# Observation:
# 1.Online deliveries are available in india and UAE

# %%
#crete apie chart for cities distributions
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
homedelivery
# Out:
#            Country Has Online delivery  \
# 0        Australia                  No
# 1           Brazil                  No
# 2           Canada                  No
# 3            India                  No
# 4            India                 Yes
# 5        Indonesia                  No
# 6      New Zealand                  No
# 7      Phillipines                  No
# 8            Qatar                  No
# 9        Singapore                  No
# 10    South Africa                  No
# 11       Sri Lanka                  No
# 12          Turkey                  No
# 13             UAE                  No
# 14             UAE                 Yes
# 15  United Kingdom                  No
# 16   United States                  No
#
#     <bound method DataFrameGroupBy.value_counts of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000020A31E0E3C0>>
# 0                                                  24
# 1                                                  60
# ...

# %%
# Filter for rows where 'Has Online delivery' is 'Yes', then group by 'Country' and 'City'
final[final['Has Online delivery'] == 'Yes'].groupby(['Country', 'City']).size().reset_index(name='Count')
# Out:
#    Country          City  Count
# 0    India     Ahmedabad     11
# 1    India     Bangalore      7
# 2    India    Chandigarh      6
# 3    India       Chennai     13
# 4    India    Coimbatore      7
# 5    India     Faridabad     35
# 6    India     Ghaziabad     10
# 7    India       Gurgaon    425
# 8    India     Hyderabad      7
# 9    India        Jaipur     10
# 10   India         Kochi      5
# 11   India       Kolkata      8
# 12   India        Mohali      1
# 13   India        Mumbai      7
# 14   India        Nagpur     10
# 15   India     New Delhi   1489
# 16   India         Noida    364
# 17   India          Pune      7
# 18   India  Secunderabad      1
# 19     UAE     Abu Dhabi     11
# 20     UAE         Dubai      6
# 21     UAE       Sharjah     11

# %%
final.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#        'Bhubaneshwar', 'Lucknow', 'Ahmedabad', 'Amritsar', 'Guwahati',
#        ...
#        'Forrest', 'East Ballina', 'Huskisson', 'Inverloch', 'Lakeview',
#        'Lakes Entrance', 'Mohali', 'Panchkula', 'Bandung', 'Randburg'],
#       dtype='object', name='City', length=141)

# %%
city_values=final.City.value_counts().values
city_labels=final.City.value_counts().index

# %%
import matplotlib.pyplot as plt
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20a33a89790>,
# ...
#  [Text(-0.6145353730323401, 0.9123301350344637, 'New Delhi'),
#   Text(0.06236774886414425, -1.0982305149200777, 'Gurgaon'),
#   Text(0.878904221413572, -0.6614585169014024, 'Noida'),
#   Text(1.0922218482114119, -0.1305811406354216, 'Faridabad'),
#   Text(1.099946277419523, -0.010871374841004297, 'Ghaziabad')],
#  [Text(-0.33520111256309454, 0.4976346191097074, '68.87%'),
#   Text(0.03401877210771504, -0.5990348263200423, '14.07%'),
#   Text(0.479402302589221, -0.36079555467349217, '13.59%'),
#   Text(0.5957573717516791, -0.07122607671022996, '3.16%'),
#   Text(0.5999706967742853, -0.00592984082236598, '0.31%')])

# %%
#find th top 10 cuisuines
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final.groupby(['Restaurant ID', 'Cuisines']).size().reset_index(name='Count')
# Out:
#       Restaurant ID                        Cuisines  Count
# 0                53  North Indian, Chinese, Mughlai      1
# 1                55                   Chinese, Thai      1
# 2                60           North Indian, Mughlai      1
# 3                64                         Italian      1
# 4                65          Chinese, Seafood, Thai      1
# ...             ...                             ...    ...
# 9537       18499493           Chinese, North Indian      1
# 9538       18500618           North Indian, Chinese      1
# 9539       18500628  Chinese, Mughlai, North Indian      1
# 9540       18500639           North Indian, Chinese      1
# 9541       18500652                    North Indian      1
#
# [9542 rows x 3 columns]

# %%
from collections import Counter

# Drop missing values in 'Cuisines'
cuisine_series = final['Cuisines'].dropna().str.split(', ')

# Flatten the list and count each cuisine
cuisine_counts = Counter([cuisine for sublist in cuisine_series for cuisine in sublist])

# Get the top 10 cuisines
pd.Series(cuisine_counts).sort_values(ascending=False).head(10)
# Out:
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Mughlai          995
# Italian          764
# Bakery           745
# Continental      736
# Cafe             703
# Desserts         653
# South Indian     636
# dtype: int64
